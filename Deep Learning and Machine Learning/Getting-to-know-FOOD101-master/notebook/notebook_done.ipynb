# %% [markdown]
# # Working with FOOD101 dataset

# %% [markdown]
# #### The three lines of code ensure that any edits to libraries you make are reloaded here automatically, and also that any charts or images displayed are shown in this notebook.

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# #### Importing all the necessary packages.

# %%
from fastai.vision import *
from fastai.metrics import error_rate
import errno
import os
import shutil

# %% [markdown]
# #### Providing the path name for the dataset

# %%
path = Path('/home/jupyter/fellowship/food-101/')
print(path)
# Out:
# /home/jupyter/fellowship/food-101

# %% [markdown]
# #### Lisiting the files in food-101

# %%
path.ls()
# Out:
# [PosixPath('/home/jupyter/fellowship/food-101/README.txt'),
#  PosixPath('/home/jupyter/fellowship/food-101/images'),
#  PosixPath('/home/jupyter/fellowship/food-101/valid'),
#  PosixPath('/home/jupyter/fellowship/food-101/license_agreement.txt'),
#  PosixPath('/home/jupyter/fellowship/food-101/test'),
#  PosixPath('/home/jupyter/fellowship/food-101/train'),
#  PosixPath('/home/jupyter/fellowship/food-101/meta'),
#  PosixPath('/home/jupyter/fellowship/food-101/models')]

# %%
len(path.ls())
# Out:
# 8

# %% [markdown]
# #### Providing a batch size, need to check if the gpu can take up that much data,

# %%
bs = 64
#need to check the batch size

# %% [markdown]
# #### Providing path for the images folder

# %%
path_img = path/'images'
print(path_img)
# Out:
# /home/jupyter/fellowship/food-101/images

# %%
path_img.ls()
# Out:
# [PosixPath('/home/jupyter/fellowship/food-101/images/carrot_cake'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/french_onion_soup'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/clam_chowder'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/takoyaki'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/breakfast_burrito'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/panna_cotta'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/baklava'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/seaweed_salad'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/strawberry_shortcake'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/steak'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/ravioli'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/spring_rolls'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/apple_pie'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/club_sandwich'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/scallops'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/spaghetti_bolognese'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/gnocchi'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/frozen_yogurt'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/cheesecake'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/ice_cream'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/caprese_salad'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/tacos'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/churros'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/ceviche'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/sashimi'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/mussels'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/chicken_wings'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/garlic_bread'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/crab_cakes'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/pulled_pork_sandwich'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/lasagna'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/greek_salad'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/onion_rings'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/creme_brulee'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/pizza'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/hamburger'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/waffles'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/guacamole'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/chicken_quesadilla'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/hummus'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/red_velvet_cake'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/eggs_benedict'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/grilled_cheese_sandwich'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/escargots'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/nachos'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/pho'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/edamame'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/beignets'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/caesar_salad'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/cannoli'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/poutine'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/pad_thai'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/dumplings'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/risotto'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/beef_carpaccio'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/cheese_plate'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/tuna_tartare'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/pork_chop'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/grilled_salmon'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/peking_duck'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/french_toast'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/macarons'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/shrimp_and_grits'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/bread_pudding'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/omelette'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/lobster_roll_sandwich'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/chocolate_cake'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/french_fries'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/cup_cakes'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/deviled_eggs'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/bibimbap'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/falafel'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/donuts'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/chocolate_mousse'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/fish_and_chips'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/croque_madame'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/pancakes'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/spaghetti_carbonara'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/beet_salad'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/huevos_rancheros'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/filet_mignon'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/beef_tartare'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/foie_gras'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/sushi'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/gyoza'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/tiramisu'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/prime_rib'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/lobster_bisque'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/fried_calamari'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/baby_back_ribs'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/miso_soup'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/bruschetta'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/hot_dog'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/fried_rice'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/macaroni_and_cheese'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/chicken_curry'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/paella'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/oysters'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/hot_and_sour_soup'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/ramen'),
#  PosixPath('/home/jupyter/fellowship/food-101/images/samosa')]

# %%
len(path_img.ls())
# Out:
# 101

# %%
path_meta = path/'meta'

# %%
path_meta.ls()
# Out:
# [PosixPath('/home/jupyter/fellowship/food-101/meta/train.json'),
#  PosixPath('/home/jupyter/fellowship/food-101/meta/test.txt'),
#  PosixPath('/home/jupyter/fellowship/food-101/meta/train.txt'),
#  PosixPath('/home/jupyter/fellowship/food-101/meta/test.json'),
#  PosixPath('/home/jupyter/fellowship/food-101/meta/labels.txt'),
#  PosixPath('/home/jupyter/fellowship/food-101/meta/classes.txt')]

# %%
path_train=path_meta/'train.txt'

# %%
with open(path_train) as f:
     train_list=f.read().splitlines()

# %% [markdown]
# #### Reading the files from the train_list

# %%
print(len(train_list))
# Out:
# 75750

# %%
train_list[0]+'.jpg'
# Out:
# 'apple_pie/1005649.jpg'

# %% [markdown]
# #### Getting the classes from the class file

# %%
path_class = path/'meta/classes.txt'
with open(path_class) as f:
    classes = f.read().splitlines()
print(classes)
# Out:
# ['apple_pie', 'baby_back_ribs', 'baklava', 'beef_carpaccio', 'beef_tartare', 'beet_salad', 'beignets', 'bibimbap', 'bread_pudding', 'breakfast_burrito', 'bruschetta', 'caesar_salad', 'cannoli', 'caprese_salad', 'carrot_cake', 'ceviche', 'cheesecake', 'cheese_plate', 'chicken_curry', 'chicken_quesadilla', 'chicken_wings', 'chocolate_cake', 'chocolate_mousse', 'churros', 'clam_chowder', 'club_sandwich', 'crab_cakes', 'creme_brulee', 'croque_madame', 'cup_cakes', 'deviled_eggs', 'donuts', 'dumplings', 'edamame', 'eggs_benedict', 'escargots', 'falafel', 'filet_mignon', 'fish_and_chips', 'foie_gras', 'french_fries', 'french_onion_soup', 'french_toast', 'fried_calamari', 'fried_rice', 'frozen_yogurt', 'garlic_bread', 'gnocchi', 'greek_salad', 'grilled_cheese_sandwich', 'grilled_salmon', 'guacamole', 'gyoza', 'hamburger', 'hot_and_sour_soup', 'hot_dog', 'huevos_rancheros', 'hummus', 'ice_cream', 'lasagna', 'lobster_bisque', 'lobster_roll_sandwich', 'macaroni_and_cheese', 'macarons', 'miso_soup', 'mussels', 'nachos', 'omelette', 'onion_rings', 'oysters', 'pad_thai', 'paella', 'pancakes', 'panna_cotta', 'peking_duck', 'pho', 'pizza', 'pork_chop', 'poutine', 'prime_rib', 'pulled_pork_sandwich', 'ramen', 'ravioli', 'red_velvet_cake', 'risotto', 'samosa', 'sashimi', 'scallops', 'seaweed_salad', 'shrimp_and_grits', 'spaghetti_bolognese', 'spaghetti_carbonara', 'spring_rolls', 'steak', 'strawberry_shortcake', 'sushi', 'tacos', 'takoyaki', 'tiramisu', 'tuna_tartare', 'waffles']

# %% [markdown]
# #### Creating directories from test and train dataset

# %%
os.makedirs(path/'test')
os.makedirs(path/'train')
#os.makedirs(path/'valid')

# %% [markdown]
# #### Creating classes directories from train dataset

# %%
for i in range(len(classes)):
    os.makedirs('/home/jupyter/fellowship/food-101/train/'+classes[i])

# %% [markdown]
# checking for one file
# #shutil.copy('/home/jupyter/fellowship/food-101/images/'+train_list[0]+'.jpg','/home/jupyter/fellowship/food-101/train/'+train_list[0]+'.jpg')

# %% [markdown]
# #### Copying the data from the images folder to the train folder

# %%
for i in range(len(train_list)):
    #shutil.move("path/to/current/file.foo", "path/to/new/destination/for/file.foo")
    shutil.copy('/home/jupyter/fellowship/food-101/images/'+train_list[i]+'.jpg','/home/jupyter/fellowship/food-101/train/'+train_list[i]+'.jpg')

# %%
path_img_train=path/'train'
len(path_img_train.ls())
# Out:
# 101

# %%
# !ls
# Out:
# fellowhip-FOOD101.ipynb  food-101.tar.gz		       Untitled.ipynb
# food-101		 open?id=0B7EVK8r0v71pWEZsZE9oNnFzTm8

# %% [markdown]
# #### Creating classes directories from test dataset

# %%
for i in range(len(classes)):
    os.makedirs('/home/jupyter/fellowship/food-101/test/'+classes[i])

# %% [markdown]
# #### Reading the files from the test_list

# %%
path_test=path_meta/'test.txt'

# %%
with open(path_test) as f:
     test_list=f.read().splitlines()

# %%
print(len(test_list))
# Out:
# 25250

# %%
print(test_list[0])
# Out:
# apple_pie/1011328

# %% [markdown]
# #### Copying the data from the images folder to the train folder

# %%
for i in range(len(test_list)):
    #shutil.move("path/to/current/file.foo", "path/to/new/destination/for/file.foo")
    shutil.copy('/home/jupyter/fellowship/food-101/images/'+test_list[i]+'.jpg','/home/jupyter/fellowship/food-101/test/'+test_list[i]+'.jpg')

# %%
path_img_test=path/'test'
len(path_img_test.ls())
# Out:
# 101

# %%
print(len(os.listdir(path_img_train)))
# Out:
# 101
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-d785d33fc375> in <module>
#       1 print(len(os.listdir(path_img_train)))
# ----> 2 print(len(os.listdir(path_img_valid)))
#
# NameError: name 'path_img_valid' is not defined

# %%
??ImageDataBunch.from_folder

# %%
path
# Out:
# PosixPath('/home/jupyter/fellowship/food-101')

# %%
path_img_train
# Out:
# PosixPath('/home/jupyter/fellowship/food-101/train')

# %% [markdown]
# #### Getting the data from the folders, size is specified

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path,train="train", valid="test",ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %% [markdown]
# #### Printing the length of training and testing

# %%
len(data.train_ds), len(data.valid_ds)
# Out:
# (75750, 25250)

# %%
data.classes
# Out:
# ['apple_pie',
#  'baby_back_ribs',
#  'baklava',
#  'beef_carpaccio',
#  'beef_tartare',
#  'beet_salad',
#  'beignets',
#  'bibimbap',
#  'bread_pudding',
#  'breakfast_burrito',
#  'bruschetta',
#  'caesar_salad',
#  'cannoli',
#  'caprese_salad',
#  'carrot_cake',
#  'ceviche',
#  'cheese_plate',
#  'cheesecake',
#  'chicken_curry',
#  'chicken_quesadilla',
#  'chicken_wings',
#  'chocolate_cake',
#  'chocolate_mousse',
#  'churros',
#  'clam_chowder',
#  'club_sandwich',
#  'crab_cakes',
#  'creme_brulee',
#  'croque_madame',
#  'cup_cakes',
#  'deviled_eggs',
#  'donuts',
#  'dumplings',
#  'edamame',
#  'eggs_benedict',
#  'escargots',
#  'falafel',
#  'filet_mignon',
#  'fish_and_chips',
#  'foie_gras',
#  'french_fries',
#  'french_onion_soup',
#  'french_toast',
#  'fried_calamari',
#  'fried_rice',
#  'frozen_yogurt',
#  'garlic_bread',
#  'gnocchi',
#  'greek_salad',
#  'grilled_cheese_sandwich',
#  'grilled_salmon',
#  'guacamole',
#  'gyoza',
#  'hamburger',
#  'hot_and_sour_soup',
#  'hot_dog',
#  'huevos_rancheros',
#  'hummus',
#  'ice_cream',
#  'lasagna',
#  'lobster_bisque',
#  'lobster_roll_sandwich',
#  'macaroni_and_cheese',
#  'macarons',
#  'miso_soup',
#  'mussels',
#  'nachos',
#  'omelette',
#  'onion_rings',
#  'oysters',
#  'pad_thai',
#  'paella',
#  'pancakes',
#  'panna_cotta',
#  'peking_duck',
#  'pho',
#  'pizza',
#  'pork_chop',
#  'poutine',
#  'prime_rib',
#  'pulled_pork_sandwich',
#  'ramen',
#  'ravioli',
#  'red_velvet_cake',
#  'risotto',
#  'samosa',
#  'sashimi',
#  'scallops',
#  'seaweed_salad',
#  'shrimp_and_grits',
#  'spaghetti_bolognese',
#  'spaghetti_carbonara',
#  'spring_rolls',
#  'steak',
#  'strawberry_shortcake',
#  'sushi',
#  'tacos',
#  'takoyaki',
#  'tiramisu',
#  'tuna_tartare',
#  'waffles']

# %%
print(len(data.classes))
# Out:
# 101

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(4)
# Out:
# Total time: 51:41 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.125558</td>
#       <td>1.505197</td>
#       <td>0.400317</td>
#       <td>13:19</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.805222</td>
#       <td>1.227178</td>
#       <td>0.327842</td>
#       <td>12:49</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.654382</td>
#       <td>1.096082</td>
#       <td>0.293663</td>
#       <td>12:47</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.524474</td>
#       <td>1.059225</td>
#       <td>0.284356</td>
#       <td>12:44</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1-34')

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
interp.most_confused(min_val=2)
# Out:
# [('steak', 'filet_mignon', 40),
#  ('filet_mignon', 'steak', 31),
#  ('tuna_tartare', 'beef_tartare', 26),
#  ('ceviche', 'greek_salad', 23),
#  ('pork_chop', 'filet_mignon', 23),
#  ('cheesecake', 'strawberry_shortcake', 21),
#  ('chocolate_cake', 'chocolate_mousse', 21),
#  ('chocolate_mousse', 'chocolate_cake', 21),
#  ('club_sandwich', 'grilled_cheese_sandwich', 21),
#  ('steak', 'prime_rib', 21),
#  ('beef_tartare', 'tuna_tartare', 20),
#  ('pork_chop', 'grilled_salmon', 18),
#  ('prime_rib', 'steak', 18),
#  ('pulled_pork_sandwich', 'hamburger', 18),
#  ('steak', 'baby_back_ribs', 18),
#  ('filet_mignon', 'prime_rib', 17),
#  ('hamburger', 'pulled_pork_sandwich', 17),
#  ('pork_chop', 'steak', 17),
#  ('falafel', 'crab_cakes', 16),
#  ('filet_mignon', 'pork_chop', 16),
#  ('risotto', 'fried_rice', 16),
#  ('steak', 'pork_chop', 16),
#  ('apple_pie', 'bread_pudding', 15),
#  ('bread_pudding', 'apple_pie', 15),
#  ('chocolate_mousse', 'panna_cotta', 15),
#  ('clam_chowder', 'lobster_bisque', 15),
#  ('crab_cakes', 'scallops', 15),
#  ('donuts', 'cup_cakes', 15),
#  ('hummus', 'chicken_quesadilla', 15),
#  ('ice_cream', 'frozen_yogurt', 15),
#  ('ramen', 'pho', 15),
#  ('ravioli', 'shrimp_and_grits', 15),
#  ('scallops', 'foie_gras', 15),
#  ('tiramisu', 'chocolate_mousse', 15),
#  ('foie_gras', 'cheese_plate', 14),
#  ('lobster_bisque', 'clam_chowder', 14),
#  ('panna_cotta', 'chocolate_mousse', 14),
#  ('beet_salad', 'greek_salad', 13),
#  ('bruschetta', 'caprese_salad', 13),
#  ('dumplings', 'gyoza', 13),
#  ('foie_gras', 'scallops', 13),
#  ('french_onion_soup', 'creme_brulee', 13),
#  ('grilled_cheese_sandwich', 'club_sandwich', 13),
#  ('grilled_salmon', 'pork_chop', 13),
#  ('ice_cream', 'chocolate_mousse', 13),
#  ('ravioli', 'gnocchi', 13),
#  ('spaghetti_bolognese', 'spaghetti_carbonara', 13),
#  ('sushi', 'sashimi', 13),
#  ('tiramisu', 'chocolate_cake', 13),
#  ('apple_pie', 'baklava', 12),
#  ('beef_carpaccio', 'caprese_salad', 12),
#  ('beet_salad', 'caprese_salad', 12),
#  ('caprese_salad', 'greek_salad', 12),
#  ('chicken_wings', 'fish_and_chips', 12),
#  ('panna_cotta', 'strawberry_shortcake', 12),
#  ('pizza', 'lasagna', 12),
#  ('poutine', 'french_fries', 12),
#  ('tacos', 'breakfast_burrito', 12),
#  ('baby_back_ribs', 'steak', 11),
#  ('breakfast_burrito', 'chicken_quesadilla', 11),
#  ('breakfast_burrito', 'huevos_rancheros', 11),
#  ('caesar_salad', 'greek_salad', 11),
#  ('donuts', 'beignets', 11),
#  ('french_onion_soup', 'hot_and_sour_soup', 11),
#  ('omelette', 'huevos_rancheros', 11),
#  ('ravioli', 'lasagna', 11),
#  ('risotto', 'shrimp_and_grits', 11),
#  ('samosa', 'baklava', 11),
#  ('scallops', 'crab_cakes', 11),
#  ('scallops', 'deviled_eggs', 11),
#  ('scallops', 'shrimp_and_grits', 11),
#  ('seaweed_salad', 'beet_salad', 11),
#  ('shrimp_and_grits', 'gnocchi', 11),
#  ('tiramisu', 'carrot_cake', 11),
#  ('baby_back_ribs', 'pork_chop', 10),
#  ('beignets', 'donuts', 10),
#  ('caprese_salad', 'bruschetta', 10),
#  ('chocolate_cake', 'red_velvet_cake', 10),
#  ('chocolate_mousse', 'tiramisu', 10),
#  ('fried_rice', 'risotto', 10),
#  ('gnocchi', 'macaroni_and_cheese', 10),
#  ('greek_salad', 'beet_salad', 10),
#  ('greek_salad', 'caesar_salad', 10),
#  ('greek_salad', 'caprese_salad', 10),
#  ('nachos', 'tacos', 10),
#  ('tacos', 'nachos', 10),
#  ('apple_pie', 'waffles', 9),
#  ('baby_back_ribs', 'peking_duck', 9),
#  ('baklava', 'apple_pie', 9),
#  ('beef_carpaccio', 'beet_salad', 9),
#  ('bread_pudding', 'french_toast', 9),
#  ('breakfast_burrito', 'omelette', 9),
#  ('ceviche', 'shrimp_and_grits', 9),
#  ('cheesecake', 'tiramisu', 9),
#  ('chicken_curry', 'lobster_bisque', 9),
#  ('chicken_curry', 'shrimp_and_grits', 9),
#  ('chicken_wings', 'fried_calamari', 9),
#  ('chocolate_cake', 'tiramisu', 9),
#  ('eggs_benedict', 'croque_madame', 9),
#  ('foie_gras', 'beet_salad', 9),
#  ('foie_gras', 'filet_mignon', 9),
#  ('foie_gras', 'pork_chop', 9),
#  ('french_toast', 'bread_pudding', 9),
#  ('french_toast', 'grilled_cheese_sandwich', 9),
#  ('gnocchi', 'ravioli', 9),
#  ('gnocchi', 'shrimp_and_grits', 9),
#  ('gyoza', 'dumplings', 9),
#  ('hamburger', 'hot_dog', 9),
#  ('huevos_rancheros', 'bruschetta', 9),
#  ('lasagna', 'pizza', 9),
#  ('pad_thai', 'spaghetti_bolognese', 9),
#  ('spaghetti_bolognese', 'pad_thai', 9),
#  ('spaghetti_carbonara', 'spaghetti_bolognese', 9),
#  ('tacos', 'falafel', 9),
#  ('tuna_tartare', 'beef_carpaccio', 9),
#  ('tuna_tartare', 'bruschetta', 9),
#  ('apple_pie', 'carrot_cake', 8),
#  ('apple_pie', 'pancakes', 8),
#  ('bread_pudding', 'carrot_cake', 8),
#  ('breakfast_burrito', 'bruschetta', 8),
#  ('caprese_salad', 'beet_salad', 8),
#  ('cheesecake', 'carrot_cake', 8),
#  ('cheesecake', 'panna_cotta', 8),
#  ('chicken_curry', 'gnocchi', 8),
#  ('chocolate_cake', 'carrot_cake', 8),
#  ('chocolate_mousse', 'ice_cream', 8),
#  ('fried_calamari', 'onion_rings', 8),
#  ('frozen_yogurt', 'ice_cream', 8),
#  ('gnocchi', 'risotto', 8),
#  ('gnocchi', 'scallops', 8),
#  ('grilled_cheese_sandwich', 'french_toast', 8),
#  ('grilled_cheese_sandwich', 'grilled_salmon', 8),
#  ('huevos_rancheros', 'nachos', 8),
#  ('lobster_bisque', 'creme_brulee', 8),
#  ('nachos', 'huevos_rancheros', 8),
#  ('omelette', 'breakfast_burrito', 8),
#  ('onion_rings', 'fried_calamari', 8),
#  ('pancakes', 'french_toast', 8),
#  ('panna_cotta', 'cheesecake', 8),
#  ('pho', 'ramen', 8),
#  ('pulled_pork_sandwich', 'club_sandwich', 8),
#  ('ravioli', 'chicken_curry', 8),
#  ('red_velvet_cake', 'tiramisu', 8),
#  ('samosa', 'breakfast_burrito', 8),
#  ('scallops', 'gnocchi', 8),
#  ('shrimp_and_grits', 'risotto', 8),
#  ('tacos', 'greek_salad', 8),
#  ('tuna_tartare', 'beet_salad', 8),
#  ('beef_tartare', 'crab_cakes', 7),
#  ('breakfast_burrito', 'tacos', 7),
#  ('ceviche', 'tacos', 7),
#  ('chicken_quesadilla', 'breakfast_burrito', 7),
#  ('crab_cakes', 'falafel', 7),
#  ('croque_madame', 'eggs_benedict', 7),
#  ('croque_madame', 'grilled_cheese_sandwich', 7),
#  ('cup_cakes', 'donuts', 7),
#  ('escargots', 'french_onion_soup', 7),
#  ('falafel', 'tacos', 7),
#  ('french_toast', 'beignets', 7),
#  ('gnocchi', 'ceviche', 7),
#  ('hot_dog', 'french_fries', 7),
#  ('huevos_rancheros', 'omelette', 7),
#  ('huevos_rancheros', 'tacos', 7),
#  ('lasagna', 'huevos_rancheros', 7),
#  ('lasagna', 'spaghetti_bolognese', 7),
#  ('lobster_roll_sandwich', 'pulled_pork_sandwich', 7),
#  ('macaroni_and_cheese', 'risotto', 7),
#  ('miso_soup', 'hot_and_sour_soup', 7),
#  ('nachos', 'guacamole', 7),
#  ('omelette', 'grilled_cheese_sandwich', 7),
#  ('pork_chop', 'chicken_wings', 7),
#  ('pork_chop', 'crab_cakes', 7),
#  ('prime_rib', 'baby_back_ribs', 7),
#  ('ravioli', 'macaroni_and_cheese', 7),
#  ('risotto', 'macaroni_and_cheese', 7),
#  ('samosa', 'spring_rolls', 7),
#  ('sashimi', 'sushi', 7),
#  ('tacos', 'huevos_rancheros', 7),
#  ('tuna_tartare', 'ceviche', 7),
#  ('apple_pie', 'donuts', 6),
#  ('beet_salad', 'caesar_salad', 6),
#  ('beet_salad', 'seaweed_salad', 6),
#  ('beignets', 'cannoli', 6),
#  ('bread_pudding', 'panna_cotta', 6),
#  ('bread_pudding', 'tiramisu', 6),
#  ('bread_pudding', 'waffles', 6),
#  ('bruschetta', 'lobster_roll_sandwich', 6),
#  ('bruschetta', 'tuna_tartare', 6),
#  ('caesar_salad', 'tacos', 6),
#  ('caprese_salad', 'beef_carpaccio', 6),
#  ('carrot_cake', 'tiramisu', 6),
#  ('ceviche', 'beet_salad', 6),
#  ('ceviche', 'scallops', 6),
#  ('cheesecake', 'chocolate_cake', 6),
#  ('chicken_curry', 'fried_rice', 6),
#  ('chocolate_cake', 'cup_cakes', 6),
#  ('chocolate_mousse', 'foie_gras', 6),
#  ('chocolate_mousse', 'lobster_bisque', 6),
#  ('churros', 'french_fries', 6),
#  ('club_sandwich', 'hamburger', 6),
#  ('crab_cakes', 'takoyaki', 6),
#  ('croque_madame', 'huevos_rancheros', 6),
#  ('cup_cakes', 'red_velvet_cake', 6),
#  ('falafel', 'breakfast_burrito', 6),
#  ('falafel', 'greek_salad', 6),
#  ('filet_mignon', 'bread_pudding', 6),
#  ('foie_gras', 'bread_pudding', 6),
#  ('foie_gras', 'cheesecake', 6),
#  ('fried_rice', 'pad_thai', 6),
#  ('frozen_yogurt', 'greek_salad', 6),
#  ('garlic_bread', 'omelette', 6),
#  ('gnocchi', 'escargots', 6),
#  ('grilled_cheese_sandwich', 'garlic_bread', 6),
#  ('grilled_salmon', 'steak', 6),
#  ('guacamole', 'caesar_salad', 6),
#  ('hamburger', 'steak', 6),
#  ('hot_and_sour_soup', 'pho', 6),
#  ('hot_dog', 'pulled_pork_sandwich', 6),
#  ('huevos_rancheros', 'breakfast_burrito', 6),
#  ('huevos_rancheros', 'chicken_curry', 6),
#  ('huevos_rancheros', 'croque_madame', 6),
#  ('huevos_rancheros', 'lasagna', 6),
#  ('hummus', 'risotto', 6),
#  ('lasagna', 'french_onion_soup', 6),
#  ('lasagna', 'omelette', 6),
#  ('lobster_roll_sandwich', 'hot_dog', 6),
#  ('macaroni_and_cheese', 'lasagna', 6),
#  ('omelette', 'lasagna', 6),
#  ('omelette', 'macaroni_and_cheese', 6),
#  ('onion_rings', 'donuts', 6),
#  ('paella', 'nachos', 6),
#  ('paella', 'pad_thai', 6),
#  ('panna_cotta', 'cup_cakes', 6),
#  ('pork_chop', 'prime_rib', 6),
#  ('pork_chop', 'scallops', 6),
#  ('ramen', 'hot_and_sour_soup', 6),
#  ('red_velvet_cake', 'carrot_cake', 6),
#  ('risotto', 'paella', 6),
#  ('scallops', 'bruschetta', 6),
#  ('seaweed_salad', 'beef_carpaccio', 6),
#  ('shrimp_and_grits', 'chicken_curry', 6),
#  ('shrimp_and_grits', 'ravioli', 6),
#  ('spring_rolls', 'samosa', 6),
#  ('steak', 'crab_cakes', 6),
#  ('steak', 'grilled_salmon', 6),
#  ('strawberry_shortcake', 'bread_pudding', 6),
#  ('strawberry_shortcake', 'red_velvet_cake', 6),
#  ('takoyaki', 'crab_cakes', 6),
#  ('waffles', 'pancakes', 6),
#  ('apple_pie', 'cannoli', 5),
#  ('baby_back_ribs', 'chicken_wings', 5),
#  ('baklava', 'carrot_cake', 5),
#  ('baklava', 'foie_gras', 5),
#  ('baklava', 'samosa', 5),
#  ('beef_tartare', 'beet_salad', 5),
#  ('beef_tartare', 'bruschetta', 5),
#  ('beet_salad', 'beef_carpaccio', 5),
#  ('beet_salad', 'ceviche', 5),
#  ('bibimbap', 'croque_madame', 5),
#  ('bibimbap', 'huevos_rancheros', 5),
#  ('bibimbap', 'pad_thai', 5),
#  ('bread_pudding', 'lasagna', 5),
#  ('breakfast_burrito', 'pulled_pork_sandwich', 5),
#  ('bruschetta', 'huevos_rancheros', 5),
#  ('bruschetta', 'scallops', 5),
#  ('bruschetta', 'takoyaki', 5),
#  ('caesar_salad', 'guacamole', 5),
#  ('carrot_cake', 'red_velvet_cake', 5),
#  ('ceviche', 'caesar_salad', 5),
#  ('ceviche', 'gnocchi', 5),
#  ('ceviche', 'nachos', 5),
#  ('ceviche', 'sushi', 5),
#  ('ceviche', 'tuna_tartare', 5),
#  ('cheese_plate', 'peking_duck', 5),
#  ('cheesecake', 'bread_pudding', 5),
#  ('cheesecake', 'cheese_plate', 5),
#  ('cheesecake', 'cup_cakes', 5),
#  ('cheesecake', 'red_velvet_cake', 5),
#  ('chicken_curry', 'chicken_quesadilla', 5),
#  ('chicken_curry', 'paella', 5),
#  ('chicken_quesadilla', 'hummus', 5),
#  ('chicken_quesadilla', 'nachos', 5),
#  ('chicken_quesadilla', 'tacos', 5),
#  ('chicken_wings', 'peking_duck', 5),
#  ('chocolate_cake', 'cheesecake', 5),
#  ('club_sandwich', 'french_fries', 5),
#  ('crab_cakes', 'beef_tartare', 5),
#  ('crab_cakes', 'filet_mignon', 5),
#  ('crab_cakes', 'tuna_tartare', 5),
#  ('filet_mignon', 'crab_cakes', 5),
#  ('filet_mignon', 'foie_gras', 5),
#  ('filet_mignon', 'shrimp_and_grits', 5),
#  ('fish_and_chips', 'french_fries', 5),
#  ('fish_and_chips', 'fried_calamari', 5),
#  ('foie_gras', 'grilled_salmon', 5),
#  ('foie_gras', 'panna_cotta', 5),
#  ('fried_calamari', 'chicken_wings', 5),
#  ('fried_rice', 'macaroni_and_cheese', 5),
#  ('fried_rice', 'paella', 5),
#  ('garlic_bread', 'chicken_quesadilla', 5),
#  ('garlic_bread', 'pizza', 5),
#  ('grilled_cheese_sandwich', 'fish_and_chips', 5),
#  ('grilled_salmon', 'grilled_cheese_sandwich', 5),
#  ('grilled_salmon', 'shrimp_and_grits', 5),
#  ('gyoza', 'spring_rolls', 5),
#  ('huevos_rancheros', 'beef_carpaccio', 5),
#  ('huevos_rancheros', 'falafel', 5),
#  ('hummus', 'pancakes', 5),
#  ('ice_cream', 'apple_pie', 5),
#  ('lasagna', 'shrimp_and_grits', 5),
#  ('macaroni_and_cheese', 'pizza', 5),
#  ('mussels', 'oysters', 5),
#  ('omelette', 'eggs_benedict', 5),
#  ('omelette', 'garlic_bread', 5),
#  ('paella', 'mussels', 5),
#  ('paella', 'shrimp_and_grits', 5),
#  ('pancakes', 'strawberry_shortcake', 5),
#  ('panna_cotta', 'bread_pudding', 5),
#  ('panna_cotta', 'creme_brulee', 5),
#  ('panna_cotta', 'lobster_bisque', 5),
#  ('peking_duck', 'baby_back_ribs', 5),
#  ('peking_duck', 'spring_rolls', 5),
#  ('peking_duck', 'waffles', 5),
#  ('pork_chop', 'peking_duck', 5),
#  ('poutine', 'croque_madame', 5),
#  ('prime_rib', 'beef_tartare', 5),
#  ('pulled_pork_sandwich', 'fish_and_chips', 5),
#  ('pulled_pork_sandwich', 'grilled_cheese_sandwich', 5),
#  ('pulled_pork_sandwich', 'tacos', 5),
#  ('ramen', 'chicken_curry', 5),
#  ('ramen', 'miso_soup', 5),
#  ('ravioli', 'garlic_bread', 5),
#  ('ravioli', 'scallops', 5),
#  ('red_velvet_cake', 'cheesecake', 5),
#  ('red_velvet_cake', 'chocolate_cake', 5),
#  ('shrimp_and_grits', 'fried_calamari', 5),
#  ('shrimp_and_grits', 'scallops', 5),
#  ('spring_rolls', 'baklava', 5),
#  ('tacos', 'paella', 5),
#  ('tacos', 'takoyaki', 5),
#  ('tiramisu', 'bread_pudding', 5),
#  ('tiramisu', 'panna_cotta', 5),
#  ('tuna_tartare', 'strawberry_shortcake', 5),
#  ('tuna_tartare', 'sushi', 5),
#  ('apple_pie', 'foie_gras', 4),
#  ('apple_pie', 'french_onion_soup', 4),
#  ('apple_pie', 'french_toast', 4),
#  ('apple_pie', 'gyoza', 4),
#  ('apple_pie', 'strawberry_shortcake', 4),
#  ('baklava', 'bread_pudding', 4),
#  ('beef_carpaccio', 'bruschetta', 4),
#  ('beef_tartare', 'cheese_plate', 4),
#  ('beef_tartare', 'foie_gras', 4),
#  ('beet_salad', 'beef_tartare', 4),
#  ('beet_salad', 'tuna_tartare', 4),
#  ('bread_pudding', 'eggs_benedict', 4),
#  ('bread_pudding', 'macaroni_and_cheese', 4),
#  ('bread_pudding', 'strawberry_shortcake', 4),
#  ('breakfast_burrito', 'cheese_plate', 4),
#  ('breakfast_burrito', 'hot_dog', 4),
#  ('breakfast_burrito', 'spring_rolls', 4),
#  ('bruschetta', 'beet_salad', 4),
#  ('bruschetta', 'ceviche', 4),
#  ('bruschetta', 'greek_salad', 4),
#  ('bruschetta', 'grilled_salmon', 4),
#  ('caesar_salad', 'beet_salad', 4),
#  ('cannoli', 'beignets', 4),
#  ('cannoli', 'pancakes', 4),
#  ('carrot_cake', 'bread_pudding', 4),
#  ('carrot_cake', 'chocolate_mousse', 4),
#  ('carrot_cake', 'cup_cakes', 4),
#  ('ceviche', 'beef_carpaccio', 4),
#  ('ceviche', 'beef_tartare', 4),
#  ('ceviche', 'guacamole', 4),
#  ('ceviche', 'risotto', 4),
#  ('cheese_plate', 'ceviche', 4),
#  ('cheese_plate', 'foie_gras', 4),
#  ('cheese_plate', 'garlic_bread', 4),
#  ('chicken_curry', 'chicken_wings', 4),
#  ('chicken_curry', 'hot_and_sour_soup', 4),
#  ('chicken_curry', 'hummus', 4),
#  ('chicken_curry', 'ramen', 4),
#  ('chicken_curry', 'ravioli', 4),
#  ('chicken_quesadilla', 'omelette', 4),
#  ('chicken_wings', 'pork_chop', 4),
#  ('clam_chowder', 'gnocchi', 4),
#  ('club_sandwich', 'pulled_pork_sandwich', 4),
#  ('crab_cakes', 'bruschetta', 4),
#  ('crab_cakes', 'caesar_salad', 4),
#  ('creme_brulee', 'lobster_bisque', 4),
#  ('cup_cakes', 'chocolate_cake', 4),
#  ('deviled_eggs', 'tuna_tartare', 4),
#  ('filet_mignon', 'baby_back_ribs', 4),
#  ('filet_mignon', 'chocolate_cake', 4),
#  ('filet_mignon', 'scallops', 4),
#  ('fish_and_chips', 'lobster_roll_sandwich', 4),
#  ('foie_gras', 'beef_tartare', 4),
#  ('foie_gras', 'tuna_tartare', 4),
#  ('french_onion_soup', 'bread_pudding', 4),
#  ('french_onion_soup', 'lasagna', 4),
#  ('french_toast', 'chicken_wings', 4),
#  ('french_toast', 'omelette', 4),
#  ('fried_calamari', 'fish_and_chips', 4),
#  ('fried_rice', 'croque_madame', 4),
#  ('frozen_yogurt', 'strawberry_shortcake', 4),
#  ('garlic_bread', 'apple_pie', 4),
#  ('garlic_bread', 'baklava', 4),
#  ('garlic_bread', 'french_toast', 4),
#  ('garlic_bread', 'grilled_cheese_sandwich', 4),
#  ('garlic_bread', 'lasagna', 4),
#  ('garlic_bread', 'samosa', 4),
#  ('greek_salad', 'nachos', 4),
#  ('grilled_cheese_sandwich', 'chicken_quesadilla', 4),
#  ('grilled_cheese_sandwich', 'omelette', 4),
#  ('grilled_salmon', 'crab_cakes', 4),
#  ('grilled_salmon', 'garlic_bread', 4),
#  ('grilled_salmon', 'scallops', 4),
#  ('guacamole', 'ceviche', 4),
#  ('guacamole', 'nachos', 4),
#  ('gyoza', 'garlic_bread', 4),
#  ('hamburger', 'beef_tartare', 4),
#  ('hamburger', 'club_sandwich', 4),
#  ('hot_dog', 'club_sandwich', 4),
#  ('hot_dog', 'grilled_cheese_sandwich', 4),
#  ('hot_dog', 'hamburger', 4),
#  ('hot_dog', 'lobster_roll_sandwich', 4),
#  ('huevos_rancheros', 'bibimbap', 4),
#  ('huevos_rancheros', 'greek_salad', 4),
#  ('huevos_rancheros', 'ramen', 4),
#  ('hummus', 'clam_chowder', 4),
#  ('hummus', 'creme_brulee', 4),
#  ('hummus', 'omelette', 4),
#  ('lasagna', 'crab_cakes', 4),
#  ('lasagna', 'croque_madame', 4),
#  ('lasagna', 'garlic_bread', 4),
#  ('lobster_bisque', 'chicken_curry', 4),
#  ('lobster_bisque', 'miso_soup', 4),
#  ('lobster_roll_sandwich', 'bruschetta', 4),
#  ('lobster_roll_sandwich', 'ceviche', 4),
#  ('macaroni_and_cheese', 'fried_calamari', 4),
#  ('macaroni_and_cheese', 'gyoza', 4),
#  ('macarons', 'sashimi', 4),
#  ('miso_soup', 'ramen', 4),
#  ('nachos', 'caesar_salad', 4),
#  ('nachos', 'ceviche', 4),
#  ('nachos', 'pulled_pork_sandwich', 4),
#  ('omelette', 'crab_cakes', 4),
#  ('omelette', 'french_toast', 4),
#  ('omelette', 'grilled_salmon', 4),
#  ('omelette', 'pancakes', 4),
#  ('omelette', 'pizza', 4),
#  ('oysters', 'mussels', 4),
#  ('paella', 'bruschetta', 4),
#  ('paella', 'greek_salad', 4),
#  ('paella', 'tacos', 4),
#  ('pancakes', 'cheesecake', 4),
#  ('panna_cotta', 'caprese_salad', 4),
#  ('pizza', 'beef_carpaccio', 4),
#  ('pork_chop', 'baby_back_ribs', 4),
#  ('poutine', 'chicken_wings', 4),
#  ('poutine', 'pad_thai', 4),
#  ('prime_rib', 'filet_mignon', 4),
#  ('prime_rib', 'grilled_salmon', 4),
#  ('prime_rib', 'huevos_rancheros', 4),
#  ('ramen', 'bibimbap', 4),
#  ('ramen', 'spaghetti_carbonara', 4),
#  ('ravioli', 'ramen', 4),
#  ('red_velvet_cake', 'cup_cakes', 4),
#  ('red_velvet_cake', 'strawberry_shortcake', 4),
#  ('risotto', 'beef_tartare', 4),
#  ('risotto', 'caesar_salad', 4),
#  ('risotto', 'ceviche', 4),
#  ('risotto', 'pad_thai', 4),
#  ('samosa', 'apple_pie', 4),
#  ('samosa', 'chicken_quesadilla', 4),
#  ('samosa', 'chicken_wings', 4),
#  ('samosa', 'dumplings', 4),
#  ('samosa', 'gyoza', 4),
#  ('sashimi', 'spring_rolls', 4),
#  ('scallops', 'ceviche', 4),
#  ('seaweed_salad', 'greek_salad', 4),
#  ('shrimp_and_grits', 'bruschetta', 4),
#  ('shrimp_and_grits', 'hummus', 4),
#  ('shrimp_and_grits', 'macaroni_and_cheese', 4),
#  ('spaghetti_bolognese', 'huevos_rancheros', 4),
#  ('spaghetti_bolognese', 'lasagna', 4),
#  ('spaghetti_carbonara', 'pad_thai', 4),
#  ('spring_rolls', 'breakfast_burrito', 4),
#  ('steak', 'foie_gras', 4),
#  ('strawberry_shortcake', 'cheesecake', 4),
#  ('strawberry_shortcake', 'pancakes', 4),
#  ('sushi', 'ceviche', 4),
#  ('sushi', 'lobster_roll_sandwich', 4),
#  ('sushi', 'takoyaki', 4),
#  ('tacos', 'caesar_salad', 4),
#  ('tacos', 'pulled_pork_sandwich', 4),
#  ('takoyaki', 'tacos', 4),
#  ('tiramisu', 'creme_brulee', 4),
#  ('tiramisu', 'pancakes', 4),
#  ('tiramisu', 'waffles', 4),
#  ('tuna_tartare', 'caprese_salad', 4),
#  ('tuna_tartare', 'cheesecake', 4),
#  ('tuna_tartare', 'foie_gras', 4),
#  ('tuna_tartare', 'greek_salad', 4),
#  ('waffles', 'cannoli', 4),
#  ('waffles', 'poutine', 4),
#  ('apple_pie', 'beignets', 3),
#  ('apple_pie', 'grilled_cheese_sandwich', 3),
#  ('apple_pie', 'hamburger', 3),
#  ('apple_pie', 'ice_cream', 3),
#  ('apple_pie', 'pizza', 3),
#  ('apple_pie', 'samosa', 3),
#  ('apple_pie', 'tiramisu', 3),
#  ('baby_back_ribs', 'grilled_salmon', 3),
#  ('baby_back_ribs', 'pulled_pork_sandwich', 3),
#  ('baklava', 'garlic_bread', 3),
#  ('baklava', 'gnocchi', 3),
#  ('beef_tartare', 'beef_carpaccio', 3),
#  ('beef_tartare', 'omelette', 3),
#  ('beef_tartare', 'prime_rib', 3),
#  ('beet_salad', 'cheese_plate', 3),
#  ('beet_salad', 'foie_gras', 3),
#  ('beet_salad', 'frozen_yogurt', 3),
#  ('beet_salad', 'panna_cotta', 3),
#  ('beignets', 'falafel', 3),
#  ('beignets', 'french_toast', 3),
#  ('bibimbap', 'fried_rice', 3),
#  ('bibimbap', 'paella', 3),
#  ('bread_pudding', 'baklava', 3),
#  ('bread_pudding', 'beignets', 3),
#  ('bread_pudding', 'cheesecake', 3),
#  ('bread_pudding', 'crab_cakes', 3),
#  ('bread_pudding', 'french_onion_soup', 3),
#  ('bread_pudding', 'pancakes', 3),
#  ('bread_pudding', 'prime_rib', 3),
#  ('breakfast_burrito', 'baklava', 3),
#  ('breakfast_burrito', 'greek_salad', 3),
#  ('breakfast_burrito', 'grilled_cheese_sandwich', 3),
#  ('breakfast_burrito', 'nachos', 3),
#  ('bruschetta', 'cheese_plate', 3),
#  ('bruschetta', 'deviled_eggs', 3),
#  ('bruschetta', 'shrimp_and_grits', 3),
#  ('caesar_salad', 'grilled_salmon', 3),
#  ('caesar_salad', 'scallops', 3),
#  ('caesar_salad', 'seaweed_salad', 3),
#  ('cannoli', 'spring_rolls', 3),
#  ('cannoli', 'tiramisu', 3),
#  ('caprese_salad', 'eggs_benedict', 3),
#  ('caprese_salad', 'panna_cotta', 3),
#  ('caprese_salad', 'scallops', 3),
#  ('caprese_salad', 'tuna_tartare', 3),
#  ('carrot_cake', 'baklava', 3),
#  ('carrot_cake', 'cheesecake', 3),
#  ('carrot_cake', 'strawberry_shortcake', 3),
#  ('ceviche', 'deviled_eggs', 3),
#  ('ceviche', 'frozen_yogurt', 3),
#  ('ceviche', 'pad_thai', 3),
#  ('ceviche', 'paella', 3),
#  ('ceviche', 'sashimi', 3),
#  ('cheese_plate', 'beet_salad', 3),
#  ('cheese_plate', 'cannoli', 3),
#  ('cheese_plate', 'sashimi', 3),
#  ('cheese_plate', 'sushi', 3),
#  ('cheese_plate', 'waffles', 3),
#  ('cheesecake', 'baklava', 3),
#  ('cheesecake', 'grilled_cheese_sandwich', 3),
#  ('cheesecake', 'pancakes', 3),
#  ('chicken_curry', 'ceviche', 3),
#  ('chicken_curry', 'lobster_roll_sandwich', 3),
#  ('chicken_curry', 'miso_soup', 3),
#  ('chicken_curry', 'peking_duck', 3),
#  ('chicken_curry', 'risotto', 3),
#  ('chicken_quesadilla', 'bruschetta', 3),
#  ('chicken_quesadilla', 'grilled_cheese_sandwich', 3),
#  ('chicken_quesadilla', 'huevos_rancheros', 3),
#  ('chicken_wings', 'onion_rings', 3),
#  ('chocolate_cake', 'cannoli', 3),
#  ('chocolate_cake', 'peking_duck', 3),
#  ('chocolate_mousse', 'cheese_plate', 3),
#  ('chocolate_mousse', 'cheesecake', 3),
#  ('chocolate_mousse', 'cup_cakes', 3),
#  ('chocolate_mousse', 'donuts', 3),
#  ('chocolate_mousse', 'french_onion_soup', 3),
#  ('chocolate_mousse', 'red_velvet_cake', 3),
#  ('churros', 'cheese_plate', 3),
#  ('churros', 'french_toast', 3),
#  ('churros', 'onion_rings', 3),
#  ('clam_chowder', 'french_onion_soup', 3),
#  ('clam_chowder', 'hummus', 3),
#  ('club_sandwich', 'fried_calamari', 3),
#  ('crab_cakes', 'carrot_cake', 3),
#  ('crab_cakes', 'fried_calamari', 3),
#  ('crab_cakes', 'huevos_rancheros', 3),
#  ('crab_cakes', 'pad_thai', 3),
#  ('crab_cakes', 'pork_chop', 3),
#  ('crab_cakes', 'shrimp_and_grits', 3),
#  ('creme_brulee', 'foie_gras', 3),
#  ('creme_brulee', 'pancakes', 3),
#  ('creme_brulee', 'panna_cotta', 3),
#  ('croque_madame', 'fish_and_chips', 3),
#  ('croque_madame', 'hamburger', 3),
#  ('cup_cakes', 'deviled_eggs', 3),
#  ('cup_cakes', 'panna_cotta', 3),
#  ('cup_cakes', 'strawberry_shortcake', 3),
#  ('donuts', 'macarons', 3),
#  ('donuts', 'pancakes', 3),
#  ('eggs_benedict', 'deviled_eggs', 3),
#  ('eggs_benedict', 'hamburger', 3),
#  ('eggs_benedict', 'scallops', 3),
#  ('escargots', 'cheese_plate', 3),
#  ('escargots', 'foie_gras', 3),
#  ('falafel', 'caesar_salad', 3),
#  ('falafel', 'carrot_cake', 3),
#  ('falafel', 'hot_dog', 3),
#  ('falafel', 'huevos_rancheros', 3),
#  ('falafel', 'takoyaki', 3),
#  ('filet_mignon', 'beef_tartare', 3),
#  ('filet_mignon', 'hamburger', 3),
#  ('filet_mignon', 'seaweed_salad', 3),
#  ('filet_mignon', 'tuna_tartare', 3),
#  ('fish_and_chips', 'gyoza', 3),
#  ('fish_and_chips', 'onion_rings', 3),
#  ('fish_and_chips', 'pulled_pork_sandwich', 3),
#  ('fish_and_chips', 'spring_rolls', 3),
#  ('foie_gras', 'chocolate_cake', 3),
#  ('foie_gras', 'chocolate_mousse', 3),
#  ('foie_gras', 'churros', 3),
#  ('foie_gras', 'garlic_bread', 3),
#  ('foie_gras', 'grilled_cheese_sandwich', 3),
#  ('foie_gras', 'macarons', 3),
#  ('foie_gras', 'mussels', 3),
#  ('french_fries', 'churros', 3),
#  ('french_fries', 'macaroni_and_cheese', 3),
#  ('french_onion_soup', 'croque_madame', 3),
#  ('french_onion_soup', 'macaroni_and_cheese', 3),
#  ('french_toast', 'baby_back_ribs', 3),
#  ('french_toast', 'cannoli', 3),
#  ('french_toast', 'carrot_cake', 3),
#  ('french_toast', 'croque_madame', 3),
#  ('french_toast', 'garlic_bread', 3),
#  ('french_toast', 'gyoza', 3),
#  ('french_toast', 'pancakes', 3),
#  ('french_toast', 'poutine', 3),
#  ('fried_calamari', 'ceviche', 3),
#  ('fried_calamari', 'chicken_curry', 3),
#  ('fried_rice', 'bibimbap', 3),
#  ('fried_rice', 'gnocchi', 3),
#  ('fried_rice', 'omelette', 3),
#  ('frozen_yogurt', 'ceviche', 3),
#  ('frozen_yogurt', 'chocolate_mousse', 3),
#  ('garlic_bread', 'beignets', 3),
#  ('garlic_bread', 'escargots', 3),
#  ('garlic_bread', 'gyoza', 3),
#  ('gnocchi', 'bread_pudding', 3),
#  ('gnocchi', 'caprese_salad', 3),
#  ('gnocchi', 'chicken_curry', 3),
#  ('gnocchi', 'chicken_wings', 3),
#  ('gnocchi', 'hummus', 3),
#  ('gnocchi', 'spaghetti_bolognese', 3),
#  ('gnocchi', 'takoyaki', 3),
#  ('greek_salad', 'chicken_quesadilla', 3),
#  ('greek_salad', 'seaweed_salad', 3),
#  ('grilled_cheese_sandwich', 'apple_pie', 3),
#  ('grilled_cheese_sandwich', 'crab_cakes', 3),
#  ('grilled_cheese_sandwich', 'french_fries', 3),
#  ('grilled_cheese_sandwich', 'hot_dog', 3),
#  ('grilled_cheese_sandwich', 'pancakes', 3),
#  ('grilled_cheese_sandwich', 'steak', 3),
#  ('grilled_salmon', 'baby_back_ribs', 3),
#  ('grilled_salmon', 'filet_mignon', 3),
#  ('grilled_salmon', 'fish_and_chips', 3),
#  ('grilled_salmon', 'foie_gras', 3),
#  ('grilled_salmon', 'french_toast', 3),
#  ('grilled_salmon', 'prime_rib', 3),
#  ('guacamole', 'hummus', 3),
#  ('guacamole', 'ice_cream', 3),
#  ('guacamole', 'risotto', 3),
#  ('gyoza', 'chicken_quesadilla', 3),
#  ('gyoza', 'macaroni_and_cheese', 3),
#  ('gyoza', 'pork_chop', 3),
#  ('hamburger', 'caprese_salad', 3),
#  ('hamburger', 'eggs_benedict', 3),
#  ('hot_and_sour_soup', 'ramen', 3),
#  ('huevos_rancheros', 'bread_pudding', 3),
#  ('huevos_rancheros', 'eggs_benedict', 3),
#  ('huevos_rancheros', 'french_toast', 3),
#  ('huevos_rancheros', 'gnocchi', 3),
#  ('huevos_rancheros', 'lobster_roll_sandwich', 3),
#  ('huevos_rancheros', 'shrimp_and_grits', 3),
#  ('hummus', 'chicken_curry', 3),
#  ('hummus', 'dumplings', 3),
#  ('hummus', 'garlic_bread', 3),
#  ('hummus', 'gnocchi', 3),
#  ('hummus', 'greek_salad', 3),
#  ('hummus', 'grilled_cheese_sandwich', 3),
#  ('hummus', 'huevos_rancheros', 3),
#  ('ice_cream', 'oysters', 3),
#  ('ice_cream', 'sashimi', 3),
#  ('lasagna', 'grilled_salmon', 3),
#  ('lobster_bisque', 'hummus', 3),
#  ('lobster_roll_sandwich', 'gyoza', 3),
#  ('lobster_roll_sandwich', 'hamburger', 3),
#  ('lobster_roll_sandwich', 'pizza', 3),
#  ('macaroni_and_cheese', 'french_onion_soup', 3),
#  ('macaroni_and_cheese', 'gnocchi', 3),
#  ('macaroni_and_cheese', 'poutine', 3),
#  ('macaroni_and_cheese', 'shrimp_and_grits', 3),
#  ('miso_soup', 'lobster_bisque', 3),
#  ('miso_soup', 'pho', 3),
#  ('mussels', 'escargots', 3),
#  ('nachos', 'beef_carpaccio', 3),
#  ('nachos', 'paella', 3),
#  ('omelette', 'bruschetta', 3),
#  ('omelette', 'chicken_quesadilla', 3),
#  ('omelette', 'shrimp_and_grits', 3),
#  ('pad_thai', 'fried_rice', 3),
#  ('paella', 'fried_rice', 3),
#  ('pancakes', 'grilled_cheese_sandwich', 3),
#  ('pancakes', 'hamburger', 3),
#  ('pancakes', 'omelette', 3),
#  ('pancakes', 'waffles', 3),
#  ('panna_cotta', 'deviled_eggs', 3),
#  ('panna_cotta', 'hummus', 3),
#  ('peking_duck', 'breakfast_burrito', 3),
#  ('peking_duck', 'chicken_wings', 3),
#  ('pho', 'bibimbap', 3),
#  ('pork_chop', 'fish_and_chips', 3),
#  ('poutine', 'nachos', 3),
#  ('prime_rib', 'pork_chop', 3),
#  ('pulled_pork_sandwich', 'french_fries', 3),
#  ('pulled_pork_sandwich', 'lobster_roll_sandwich', 3),
#  ('ramen', 'french_onion_soup', 3),
#  ('ravioli', 'bruschetta', 3),
#  ('ravioli', 'caesar_salad', 3),
#  ('ravioli', 'ceviche', 3),
#  ('ravioli', 'greek_salad', 3),
#  ('ravioli', 'grilled_salmon', 3),
#  ('ravioli', 'poutine', 3),
#  ('red_velvet_cake', 'chocolate_mousse', 3),
#  ('risotto', 'chicken_curry', 3),
#  ('risotto', 'gnocchi', 3),
#  ('samosa', 'fish_and_chips', 3),
#  ('samosa', 'tuna_tartare', 3),
#  ('scallops', 'beet_salad', 3),
#  ('scallops', 'filet_mignon', 3),
#  ('scallops', 'hummus', 3),
#  ('scallops', 'panna_cotta', 3),
#  ('shrimp_and_grits', 'ceviche', 3),
#  ('shrimp_and_grits', 'clam_chowder', 3),
#  ('shrimp_and_grits', 'escargots', 3),
#  ('shrimp_and_grits', 'lobster_roll_sandwich', 3),
#  ('spring_rolls', 'caesar_salad', 3),
#  ('spring_rolls', 'fish_and_chips', 3),
#  ('spring_rolls', 'french_fries', 3),
#  ('spring_rolls', 'gyoza', 3),
#  ('spring_rolls', 'hot_dog', 3),
#  ('steak', 'beef_tartare', 3),
#  ('steak', 'chicken_curry', 3),
#  ('steak', 'chocolate_cake', 3),
#  ('steak', 'french_toast', 3),
#  ('steak', 'peking_duck', 3),
#  ('strawberry_shortcake', 'bruschetta', 3),
#  ('strawberry_shortcake', 'caprese_salad', 3),
#  ('strawberry_shortcake', 'ice_cream', 3),
#  ('strawberry_shortcake', 'lobster_roll_sandwich', 3),
#  ('sushi', 'bruschetta', 3),
#  ('sushi', 'hot_dog', 3),
#  ('tacos', 'beef_carpaccio', 3),
#  ('tacos', 'beet_salad', 3),
#  ('tacos', 'bruschetta', 3),
#  ('tacos', 'chicken_quesadilla', 3),
#  ('tacos', 'hot_dog', 3),
#  ('tacos', 'lobster_roll_sandwich', 3),
#  ('tacos', 'shrimp_and_grits', 3),
#  ('takoyaki', 'donuts', 3),
#  ('takoyaki', 'pad_thai', 3),
#  ('takoyaki', 'sushi', 3),
#  ('tiramisu', 'cheesecake', 3),
#  ('tiramisu', 'red_velvet_cake', 3),
#  ('tuna_tartare', 'bread_pudding', 3),
#  ('tuna_tartare', 'nachos', 3),
#  ('tuna_tartare', 'tacos', 3),
#  ('waffles', 'apple_pie', 3),
#  ('waffles', 'bread_pudding', 3),
#  ('waffles', 'french_toast', 3),
#  ('waffles', 'strawberry_shortcake', 3),
#  ('apple_pie', 'breakfast_burrito', 2),
#  ('apple_pie', 'chicken_quesadilla', 2),
#  ('apple_pie', 'chocolate_cake', 2),
#  ('apple_pie', 'cup_cakes', 2),
#  ('apple_pie', 'garlic_bread', 2),
#  ('apple_pie', 'lasagna', 2),
#  ('apple_pie', 'macaroni_and_cheese', 2),
#  ('apple_pie', 'poutine', 2),
#  ('apple_pie', 'pulled_pork_sandwich', 2),
#  ('apple_pie', 'ravioli', 2),
#  ('apple_pie', 'shrimp_and_grits', 2),
#  ('apple_pie', 'takoyaki', 2),
#  ('baby_back_ribs', 'beet_salad', 2),
#  ('baby_back_ribs', 'donuts', 2),
#  ('baby_back_ribs', 'filet_mignon', 2),
#  ('baby_back_ribs', 'fish_and_chips', 2),
#  ('baby_back_ribs', 'spaghetti_bolognese', 2),
#  ('baklava', 'beignets', 2),
#  ('baklava', 'cannoli', 2),
#  ('baklava', 'chocolate_cake', 2),
#  ('baklava', 'french_toast', 2),
#  ('baklava', 'gyoza', 2),
#  ('baklava', 'sushi', 2),
#  ('beef_carpaccio', 'club_sandwich', 2),
#  ('beef_carpaccio', 'hot_dog', 2),
#  ('beef_carpaccio', 'tacos', 2),
#  ('beef_carpaccio', 'tuna_tartare', 2),
#  ('beef_tartare', 'filet_mignon', 2),
#  ('beef_tartare', 'lobster_roll_sandwich', 2),
#  ('beef_tartare', 'panna_cotta', 2),
#  ('beef_tartare', 'scallops', 2),
#  ('beef_tartare', 'tacos', 2),
#  ('beet_salad', 'croque_madame', 2),
#  ('beet_salad', 'falafel', 2),
#  ('beet_salad', 'filet_mignon', 2),
#  ('beet_salad', 'sashimi', 2),
#  ('beet_salad', 'scallops', 2),
#  ('beet_salad', 'sushi', 2),
#  ('beet_salad', 'tacos', 2),
#  ('beet_salad', 'takoyaki', 2),
#  ('beignets', 'carrot_cake', 2),
#  ('beignets', 'waffles', 2),
#  ('bibimbap', 'nachos', 2),
#  ('bibimbap', 'pho', 2),
#  ('bread_pudding', 'breakfast_burrito', 2),
#  ('bread_pudding', 'cannoli', 2),
#  ('bread_pudding', 'chocolate_mousse', 2),
#  ('bread_pudding', 'clam_chowder', 2),
#  ('bread_pudding', 'croque_madame', 2),
#  ('bread_pudding', 'donuts', 2),
#  ('bread_pudding', 'foie_gras', 2),
#  ('bread_pudding', 'huevos_rancheros', 2),
#  ('bread_pudding', 'peking_duck', 2),
#  ('bread_pudding', 'pizza', 2),
#  ('bread_pudding', 'pork_chop', 2),
#  ('bread_pudding', 'shrimp_and_grits', 2),
#  ('bread_pudding', 'steak', 2),
#  ('breakfast_burrito', 'cannoli', 2),
#  ('breakfast_burrito', 'chicken_wings', 2),
#  ('breakfast_burrito', 'club_sandwich', 2),
#  ('breakfast_burrito', 'deviled_eggs', 2),
#  ('breakfast_burrito', 'grilled_salmon', 2),
#  ('breakfast_burrito', 'gyoza', 2),
#  ('breakfast_burrito', 'lasagna', 2),
#  ('breakfast_burrito', 'pad_thai', 2),
#  ('breakfast_burrito', 'samosa', 2),
#  ('breakfast_burrito', 'shrimp_and_grits', 2),
#  ('breakfast_burrito', 'sushi', 2),
#  ('bruschetta', 'nachos', 2),
#  ('bruschetta', 'pizza', 2),
#  ('bruschetta', 'pulled_pork_sandwich', 2),
#  ('bruschetta', 'spaghetti_bolognese', 2),
#  ('caesar_salad', 'beef_carpaccio', 2),
#  ('caesar_salad', 'ceviche', 2),
#  ('caesar_salad', 'fried_rice', 2),
#  ('caesar_salad', 'omelette', 2),
#  ('caesar_salad', 'pad_thai', 2),
#  ('cannoli', 'apple_pie', 2),
#  ('cannoli', 'baklava', 2),
#  ('cannoli', 'breakfast_burrito', 2),
#  ('cannoli', 'caprese_salad', 2),
#  ('cannoli', 'chocolate_cake', 2),
#  ('cannoli', 'gyoza', 2),
#  ('cannoli', 'macarons', 2),
#  ('cannoli', 'sushi', 2),
#  ('caprese_salad', 'caesar_salad', 2),
#  ('caprese_salad', 'cheese_plate', 2),
#  ('caprese_salad', 'deviled_eggs', 2),
#  ('caprese_salad', 'ravioli', 2),
#  ('caprese_salad', 'sashimi', 2),
#  ('caprese_salad', 'strawberry_shortcake', 2),
#  ('carrot_cake', 'bibimbap', 2),
#  ('carrot_cake', 'chocolate_cake', 2),
#  ('carrot_cake', 'garlic_bread', 2),
#  ('carrot_cake', 'ice_cream', 2),
#  ('carrot_cake', 'sushi', 2),
#  ('carrot_cake', 'waffles', 2),
#  ('ceviche', 'bruschetta', 2),
#  ('ceviche', 'caprese_salad', 2),
#  ('ceviche', 'club_sandwich', 2),
#  ('ceviche', 'huevos_rancheros', 2),
#  ('ceviche', 'spring_rolls', 2),
#  ('cheese_plate', 'cheesecake', 2),
#  ('cheese_plate', 'chicken_quesadilla', 2),
#  ('cheese_plate', 'donuts', 2),
#  ('cheese_plate', 'fish_and_chips', 2),
#  ('cheese_plate', 'french_toast', 2),
#  ('cheese_plate', 'gyoza', 2),
#  ('cheese_plate', 'ice_cream', 2),
#  ('cheese_plate', 'macarons', 2),
#  ('cheese_plate', 'strawberry_shortcake', 2),
#  ('cheesecake', 'chocolate_mousse', 2),
#  ('cheesecake', 'foie_gras', 2),
#  ('cheesecake', 'frozen_yogurt', 2),
#  ('cheesecake', 'garlic_bread', 2),
#  ('cheesecake', 'ice_cream', 2),
#  ('cheesecake', 'risotto', 2),
#  ('chicken_curry', 'apple_pie', 2),
#  ('chicken_curry', 'bread_pudding', 2),
#  ('chicken_curry', 'caesar_salad', 2),
#  ('chicken_curry', 'french_onion_soup', 2),
#  ('chicken_curry', 'fried_calamari', 2),
#  ('chicken_curry', 'macaroni_and_cheese', 2),
#  ('chicken_curry', 'poutine', 2),
#  ('chicken_curry', 'spaghetti_bolognese', 2),
#  ('chicken_quesadilla', 'beef_carpaccio', 2),
#  ('chicken_quesadilla', 'ceviche', 2),
#  ('chicken_quesadilla', 'club_sandwich', 2),
#  ('chicken_quesadilla', 'falafel', 2),
#  ('chicken_quesadilla', 'grilled_salmon', 2),
#  ('chicken_quesadilla', 'pizza', 2),
#  ('chicken_wings', 'baby_back_ribs', 2),
#  ('chicken_wings', 'bread_pudding', 2),
#  ('chicken_wings', 'french_toast', 2),
#  ('chicken_wings', 'nachos', 2),
#  ('chicken_wings', 'steak', 2),
#  ('chocolate_cake', 'french_toast', 2),
#  ('chocolate_cake', 'panna_cotta', 2),
#  ('chocolate_cake', 'strawberry_shortcake', 2),
#  ('chocolate_mousse', 'beignets', 2),
#  ('chocolate_mousse', 'bread_pudding', 2),
#  ('chocolate_mousse', 'churros', 2),
#  ('chocolate_mousse', 'frozen_yogurt', 2),
#  ('chocolate_mousse', 'macarons', 2),
#  ('chocolate_mousse', 'pancakes', 2),
#  ('chocolate_mousse', 'peking_duck', 2),
#  ('chocolate_mousse', 'strawberry_shortcake', 2),
#  ('chocolate_mousse', 'tuna_tartare', 2),
#  ('churros', 'baby_back_ribs', 2),
#  ('churros', 'cannoli', 2),
#  ('churros', 'carrot_cake', 2),
#  ('churros', 'chocolate_mousse', 2),
#  ('churros', 'garlic_bread', 2),
#  ('churros', 'macarons', 2),
#  ('churros', 'peking_duck', 2),
#  ('churros', 'tiramisu', 2),
#  ('clam_chowder', 'beignets', 2),
#  ('clam_chowder', 'ceviche', 2),
#  ('clam_chowder', 'creme_brulee', 2),
#  ('clam_chowder', 'grilled_cheese_sandwich', 2),
#  ('clam_chowder', 'macaroni_and_cheese', 2),
#  ('clam_chowder', 'miso_soup', 2),
#  ('clam_chowder', 'ramen', 2),
#  ('clam_chowder', 'ravioli', 2),
#  ('clam_chowder', 'risotto', 2),
#  ('club_sandwich', 'cheese_plate', 2),
#  ('club_sandwich', 'spring_rolls', 2),
#  ('crab_cakes', 'bread_pudding', 2),
#  ('crab_cakes', 'breakfast_burrito', 2),
#  ('crab_cakes', 'croque_madame', 2),
#  ('crab_cakes', 'grilled_cheese_sandwich', 2),
#  ('crab_cakes', 'grilled_salmon', 2),
#  ('crab_cakes', 'hamburger', 2),
#  ('crab_cakes', 'lobster_roll_sandwich', 2),
#  ('crab_cakes', 'macaroni_and_cheese', 2),
#  ('crab_cakes', 'nachos', 2),
#  ('crab_cakes', 'ravioli', 2),
#  ('crab_cakes', 'spaghetti_bolognese', 2),
#  ('crab_cakes', 'sushi', 2),
#  ('creme_brulee', 'french_onion_soup', 2),
#  ('creme_brulee', 'hot_and_sour_soup', 2),
#  ('creme_brulee', 'strawberry_shortcake', 2),
#  ('creme_brulee', 'tiramisu', 2),
#  ('croque_madame', 'caesar_salad', 2),
#  ('croque_madame', 'club_sandwich', 2),
#  ('croque_madame', 'french_onion_soup', 2),
#  ('croque_madame', 'french_toast', 2),
#  ('cup_cakes', 'falafel', 2),
#  ('cup_cakes', 'macarons', 2),
#  ('cup_cakes', 'oysters', 2),
#  ('cup_cakes', 'waffles', 2),
#  ('deviled_eggs', 'beet_salad', 2),
#  ('deviled_eggs', 'bruschetta', 2),
#  ('deviled_eggs', 'cup_cakes', 2),
#  ('deviled_eggs', 'dumplings', 2),
#  ('deviled_eggs', 'eggs_benedict', 2),
#  ('deviled_eggs', 'french_fries', 2),
#  ('deviled_eggs', 'huevos_rancheros', 2),
#  ('deviled_eggs', 'hummus', 2),
#  ('deviled_eggs', 'omelette', 2),
#  ('deviled_eggs', 'scallops', 2),
#  ('donuts', 'baklava', 2),
#  ('donuts', 'chocolate_cake', 2),
#  ('donuts', 'hot_dog', 2),
#  ('dumplings', 'cup_cakes', 2),
#  ('eggs_benedict', 'breakfast_burrito', 2),
#  ('eggs_benedict', 'churros', 2),
#  ('eggs_benedict', 'crab_cakes', 2),
#  ('eggs_benedict', 'french_toast', 2),
#  ('eggs_benedict', 'gyoza', 2),
#  ('eggs_benedict', 'huevos_rancheros', 2),
#  ('eggs_benedict', 'omelette', 2),
#  ('eggs_benedict', 'oysters', 2),
#  ('escargots', 'creme_brulee', 2),
#  ...]

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(2)
# Out:
# Total time: 26:22 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.638733</td>
#       <td>1.307304</td>
#       <td>0.354257</td>
#       <td>13:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.042651</td>
#       <td>0.700189</td>
#       <td>0.193109</td>
#       <td>13:11</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1-34-new')

# %%
learn.load('stage-1-34-new');

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.unfreeze()
learn.fit_one_cycle(3, max_lr=slice(1e-6,1e-4))
# Out:
# Total time: 39:52 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.908507</td>
#       <td>0.677650</td>
#       <td>0.186416</td>
#       <td>13:18</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.866087</td>
#       <td>0.658682</td>
#       <td>0.183960</td>
#       <td>13:19</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.818304</td>
#       <td>0.656430</td>
#       <td>0.182416</td>
#       <td>13:15</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1-34-new1')

# %%
tfms = get_transforms(max_rotate=20, max_zoom=1.3, max_lighting=0.4, max_warp=0.4,p_affine=1., p_lighting=1.)

# %%
data_source = ImageList.from_folder(path).split_by_folder(train="train", valid="test")

# %%
def get_new_data(size, bs, padding_mode='reflection'):
    return (data_source.label_from_folder().transform(tfms, size=size, padding_mode=padding_mode).databunch(bs=bs//2).normalize(imagenet_stats))

# %%
new_data = get_new_data(224, 40, 'reflection')

# %%
learn = create_cnn(new_data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(4)
# Out:
# Total time: 54:05 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.492564</td>
#       <td>1.615018</td>
#       <td>0.424000</td>
#       <td>13:33</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.144611</td>
#       <td>1.326293</td>
#       <td>0.350218</td>
#       <td>13:30</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.891387</td>
#       <td>1.171706</td>
#       <td>0.311881</td>
#       <td>13:31</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.886463</td>
#       <td>1.123967</td>
#       <td>0.299723</td>
#       <td>13:31</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1-34-augmentation')

# %%
learn.unfreeze()

# %%
learn.recorder.plot()

# %%
learn.load('stage-1-34-augmentation');

# %%
learn.unfreeze()
learn.fit_one_cycle(3, max_lr=slice(1e-6,1e-4))
# Out:
# Total time: 41:46 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.734825</td>
#       <td>1.029811</td>
#       <td>0.275802</td>
#       <td>14:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.580540</td>
#       <td>0.929218</td>
#       <td>0.251089</td>
#       <td>13:56</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.576275</td>
#       <td>0.901517</td>
#       <td>0.244554</td>
#       <td>13:44</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1-34-augmentation-new');

# %%
learn = create_cnn(new_data, models.resnet50, metrics=error_rate)

# %%
learn.fit_one_cycle(8)
# Out:
# Total time: 2:03:33 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.219184</td>
#       <td>1.461030</td>
#       <td>0.386337</td>
#       <td>15:31</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.887946</td>
#       <td>1.234143</td>
#       <td>0.337941</td>
#       <td>15:25</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.866228</td>
#       <td>1.074659</td>
#       <td>0.294733</td>
#       <td>15:20</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.651550</td>
#       <td>0.963374</td>
#       <td>0.260673</td>
#       <td>15:23</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.565848</td>
#       <td>0.877139</td>
#       <td>0.238693</td>
#       <td>15:22</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.486919</td>
#       <td>0.828319</td>
#       <td>0.228475</td>
#       <td>15:22</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.385295</td>
#       <td>0.790571</td>
#       <td>0.219802</td>
#       <td>15:19</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.343778</td>
#       <td>0.780695</td>
#       <td>0.216158</td>
#       <td>15:48</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1-50')

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.unfreeze()
learn.fit_one_cycle(10, max_lr=slice(1e-6,1e-3))
# Out:
# Total time: 3:19:02 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.374117</td>
#       <td>0.759662</td>
#       <td>0.208752</td>
#       <td>19:54</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.349545</td>
#       <td>0.730253</td>
#       <td>0.202337</td>
#       <td>20:05</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.288046</td>
#       <td>0.694303</td>
#       <td>0.195208</td>
#       <td>20:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.172663</td>
#       <td>0.646155</td>
#       <td>0.179208</td>
#       <td>20:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.999544</td>
#       <td>0.602901</td>
#       <td>0.168911</td>
#       <td>19:49</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.019589</td>
#       <td>0.554962</td>
#       <td>0.155842</td>
#       <td>19:55</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.855234</td>
#       <td>0.519866</td>
#       <td>0.146099</td>
#       <td>19:47</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.765951</td>
#       <td>0.500502</td>
#       <td>0.140436</td>
#       <td>19:49</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.669260</td>
#       <td>0.485474</td>
#       <td>0.134614</td>
#       <td>19:49</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.706300</td>
#       <td>0.486873</td>
#       <td>0.135208</td>
#       <td>19:49</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1-50-new')

# %%
learn.load('stage-1-50-new');
