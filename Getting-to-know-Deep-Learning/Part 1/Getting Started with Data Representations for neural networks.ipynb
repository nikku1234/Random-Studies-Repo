# %% [markdown]
# Scalar

# %%
import numpy as np
x = np.array(12)
print(x)
print(x.ndim)
# Out:
# 12
# 0

# %% [markdown]
# Vector 1D Tensor

# %%
x = np.array([12,3,6,14])
print(x)
print(x.ndim)
# Out:
# [12  3  6 14]
# 1

# %% [markdown]
# Matrices 2D Tensor

# %%
x = np.array([[5,78,2,34,0],[6,79,3,35,1],[7,80,4,36,2]])
print(x)
print(x.ndim)
# Out:
# [[ 5 78  2 34  0]
#  [ 6 79  3 35  1]
#  [ 7 80  4 36  2]]
# 2

# %%
from keras.datasets import mnist
# Out:
# Using TensorFlow backend.

# %%
(train_images,train_labels),(test_images,test_labels)=mnist.load_data()

# %%
print(train_images.ndim)
# Out:
# 3

# %%
print(train_images.shape)
# Out:
# (60000, 28, 28)

# %%
print(train_images.dtype)
# Out:
# uint8

# %%
digit = train_images[4]

# %% [markdown]
# Displaying the image

# %%
import matplotlib.pyplot as plt
plt.imshow(digit, cmap=plt.cm.binary)
plt.show()

# %%
my_slice= train_images[10:100] #selecting the digits from 10 to 100 without including 100

# %%
print(my_slice.shape)
# Out:
# (90, 28, 28)

# %%
my_slice = train_images[10:100,:,:]
my_slice.shape
# Out:
# (90, 28, 28)

# %%
batch = train_images[:128]  #examples for splitting in batches
batch = train_images[128:256]

# %%
batch = train_images[128*n:128*(n+1)]
#for the nth batch
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-9b02312973f2> in <module>
# ----> 1 batch = train_images[128*n:128*(n+1)]
#
# NameError: name 'n' is not defined

# %%
#an example for keras layer

keras.layers.Dense(512, activation='relu')
output = relu(dot(W,input)+b)

# %% [markdown]
# Tensor Reshaping

# %%
x=np.array([[0,1],
          [2,3],
          [4,5]])
print(x.shape)
# Out:
# (3, 2)

# %%
x =x.reshape((6,1))

# %%
x
# Out:
# array([[0],
#        [1],
#        [2],
#        [3],
#        [4],
#        [5]])

# %%
x.reshape((2,3))
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %% [markdown]
# output = relu(dot(W,input)+b)
# equation
# w is weight
# and b is the bias
